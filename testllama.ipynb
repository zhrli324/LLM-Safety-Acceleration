# %%
from transformers import AutoTokenizer, LlamaForCausalLM

model = LlamaForCausalLM.from_pretrained("../autodl-tmp/llama/Llama-2-7b-chat-hf")
tokenizer = AutoTokenizer.from_pretrained("../autodl-tmp/llama/Llama-2-7b-chat-hf")

prompt = "Hello, how are you?"
inputs = tokenizer(prompt, return_tensors="pt")

outputs = model.generate(inputs.input_ids, max_length=50)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 9
#       6 prompt = "Hello, how are you?"
#       7 inputs = tokenizer(prompt, return_tensors="pt")
# ----> 9 outputs = model.generate(inputs.input_ids, max_length=50)
#      10 print(tokenizer.decode(outputs[0], skip_special_tokens=True))
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/transformers/src/transformers/generation/utils.py:2004, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1996     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1997         input_ids=input_ids,
#    1998         expand_size=generation_config.num_return_sequences,
#    1999         is_encoder_decoder=self.config.is_encoder_decoder,
#    2000         **model_kwargs,
#    2001     )
#    2003     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2004     result = self._sample(
#    2005         input_ids,
#    2006         logits_processor=prepared_logits_processor,
#    2007         logits_warper=prepared_logits_warper,
#    2008         stopping_criteria=prepared_stopping_criteria,
#    2009         generation_config=generation_config,
#    2010         synced_gpus=synced_gpus,
#    2011         streamer=streamer,
#    2012         **model_kwargs,
#    2013     )
#    2015 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2016     # 11. prepare logits warper
#    2017     prepared_logits_warper = (
#    2018         self._get_logits_warper(generation_config, device=input_ids.device)
#    2019         if generation_config.do_sample
#    2020         else None
#    2021     )
#
# File ~/transformers/src/transformers/generation/utils.py:2962, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2959 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    2961 # forward pass to get next token
# -> 2962 outputs = self(**model_inputs, return_dict=True)
#    2964 if synced_gpus and this_peer_finished:
#    2965     continue  # don't waste resources running the code we don't need
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/transformers/src/transformers/models/llama/modeling_llama.py:1137, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1134 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1136 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1137 outputs = self.model(
#    1138     input_ids=input_ids,
#    1139     attention_mask=attention_mask,
#    1140     position_ids=position_ids,
#    1141     past_key_values=past_key_values,
#    1142     inputs_embeds=inputs_embeds,
#    1143     use_cache=use_cache,
#    1144     output_attentions=output_attentions,
#    1145     output_hidden_states=output_hidden_states,
#    1146     return_dict=return_dict,
#    1147     cache_position=cache_position,
#    1148 )
#    1150 hidden_states = outputs[0]
#    1151 if self.config.pretraining_tp > 1:
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/transformers/src/transformers/models/llama/modeling_llama.py:937, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     934 if output_hidden_states:
#     935     all_hidden_states += (hidden_states,)
# --> 937 past_key_value = past_key_values[idx] if past_key_values is not None else None
#     939 if self.gradient_checkpointing and self.training:
#     940     layer_outputs = self._gradient_checkpointing_func(
#     941         decoder_layer.__call__,
#     942         hidden_states,
#    (...)
#     949         position_embeddings,
#     950     )
#
# File ~/transformers/src/transformers/cache_utils.py:317, in DynamicCache.__getitem__(self, layer_idx)
#     315     return (self.key_cache[layer_idx], self.value_cache[layer_idx])
#     316 else:
# --> 317     raise KeyError(f"Cache only has {len(self)} layers, attempted to access layer with index {layer_idx}")
#
# KeyError: 'Cache only has 0 layers, attempted to access layer with index 0'
